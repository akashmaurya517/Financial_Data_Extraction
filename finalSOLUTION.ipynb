# %%
import pandas as pd
import numpy as np
import json
import re
df = pd.read_csv('Results.csv')
dict_result = [{1:100}]
for z in range(len(df)):
    name_file = df.iloc[z]['Filename']
    #print(name_file)
    file_name = "Challenge Dataset/"
    with open(file_name + name_file + '.txt', 'r') as file:
        x = file.read()
        y = x.split('\n')
        y = [x.split('  ') for x in y]
        #print(y)
        
    for j in range(len(y)):
        while(y[j].count('') != 0):
            y[j].remove('')
            
    head = [y[j] for j in range(len(y) - 1) if '£' in y[j+1] or ' £' in y[j+1] or '£ ' in y[j+1] or 'Â£' in y[j+1] or ' Â£ ' in y[j+1] or 'Â£ ' in y[j+1] or ' Â£' in y[j+1]]
    
    s = 0
    e = 0
    
    for i in range(len(y)):
        if '£' in y[i] or ' £' in y[i] or '£ ' in y[i] or 'Â£' in y[i] or ' Â£ ' in y[i] or 'Â£ ' in y[i] or ' Â£' in y[i]:
            s = i
    del y[s]
    
    for i in range(len(y)):
        if 'STATEMENTS' in y[i] or ' STATEMENTS' in y[i] or 'STATEMENTS ' in y[i] or ' STATEMENTS ' in y[i]:
            e = i
            
    for i in range(len(y)):
        if 'Capital and reserves' in y[i] or ' Capital and reserves' in y[i] or 'Capital and reserves ' in y[i] or ' Capital and reserves ' in y[i]:
            e = i+1
            
    y_new = y[s-1:e]
    
    try:
        head = head[0]
    except:
        pass
    try:
        mx = 0
        l= []
        for i in range(len(y_new)):
            l.append(len(y_new[i]))
        mx= max(l)
    except:
        pass
    
    try:
        if(len(head)<mx):
            head.insert(0, 'Notes')
            y_new[0] = head
    except:
        pass
    try:
        dfs = pd.DataFrame.from_records(y_new)
        dfs.iloc[0][0] = dfs.iloc[0][0].replace(' ', '')
        dfs.columns = dfs.iloc[0]
    except:
        pass
    
    columns = []
    
    for i in range(len(dfs.columns)):
        if(dfs.columns[i] != None):
            columns.append(dfs.columns[i].replace(' ', ''))
        else:
            columns.append(dfs.columns[i])
    dfs.columns = columns
    
    try:
        dfs = dfs.drop(dfs.index[0])

        dfs.reset_index(drop=True, inplace=True)
    except:
        pass
    
    try:
        for i in range(len(dfs['2019'])):
            try:
                dfs['2019'][i] = dfs['2019'][i].replace('-', '')
                dfs['2019'][i] = dfs['2019'][i].replace(' ', '').replace('(', '-').replace(')', '').replace(',', '')
            except:
                pass
            if(dfs['Notes'][i][0] ==  ' '):
                dfs['Notes'][i] = dfs['Notes'][i][1:]
            if(dfs['Notes'][i][len(dfs['Notes'][i])-1] == ' '):
                dfs['Notes'][i] = dfs['Notes'][i][0:len(dfs['Notes'][i])-1]
    except:
        pass
    
    try:
        for i in range(len(dfs['2019'])): 
            if(dfs['2019'][i] == None ):
                dfs['2019'][i] = ''
            if(dfs['2019'][i] == '' ):
                dfs['2019'][i] = float("nan")
    except:
        pass
    
    try:
        d = dfs.set_index('Notes').to_dict()['2019']
        d = str(d).replace("\\u00c2\\u00a3", "Â£")
        #d = d.replace("\\u00c2\\u00a3", "Â£")
    except:
        pass
    
    if(df['Filename'][z] == name_file) and d != dict_result[z]:
        dict_result.append(d)
    else:
        dict_result.append({float("nan")})
# Out:
# C:\Users\Akash\Anaconda3\envs\rootenv\lib\site-packages\IPython\core\interactiveshell.py:3325: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   exec(code_obj, self.user_global_ns, self.user_ns)
# C:\Users\Akash\Anaconda3\envs\rootenv\lib\site-packages\ipykernel_launcher.py:106: UserWarning: DataFrame columns are not unique, some columns will be omitted.

# %%
dict_result
# Out:
# [{1: 100},
#  "{'Current Assets': '312', 'Creditors: amounts falling due within one year': '-59', 'Net current assets (liabilities)': '253', 'Total assets less current liabilities': '253', 'Total net assets (liabilities)': '253', 'Capital and reserves': '253'}",
#  "{'Called up share capital not paid': '1', 'Net assets': '1', 'Tssued share capital': nan, '1 Ordinary Share 1 of Â£ each': '1', 'Total Shareholder funds': '1'}",
#  "{'Net assets': '0', 'Issued share capital': nan, '1 Ordinary Share 0 of Â£ each': '0', 'Total Shareholder funds': '0'}",
#  "{'Called up share capital not paid': '1', 'Net assets': '1', 'Tssued share capital': nan, '1 Ordinary Share 1 of Â£ each': '1', 'Total Shareholder funds': '1'}",
#  "{'Current assets': nan, 'Cash at bank and in hand': '100', 'Net assets': '100', 'Issued share capital': nan, '100 Ordinary Shares 1 of Â£ each': '100', 'Total Shareholder funds': '100'}",
#  "{'Current Assets': '384', 'Creditors: amounts falling due within one year': '-225', 'Net current assets (liabilities)': '159', 'Total assets less current liabilities': '159', 'Total net assets (liabilities)': '159', 'Capital and reserves': '159'}",
#  "{'Called up share capital not paid': nan, 'Fixed Assets': '516', 'Current Assets': nan, 'Prepayments and accrued income': nan, 'Creditors: amounts falling due within one year': '0', 'Net current assets (liabilities)': '0', 'Total assets less current liabilities': '516', 'Creditors: amounts falling due after more than one year': '0', 'Provisions for liabilities': '0', 'Accruals and deferred income': '0', 'Total net assets (liabilities)': '516', 'Capital and reserves': '516'}",
#  "{'Current Assets': '23349', 'Creditors: amounts falling due within one year': '-118053', 'Net current assets (liabilities)': '-94704', 'Total assets less current liabilities': '-94704', 'Total net assets (liabilities)': '-94704', 'Capital and reserves': '-94704'}",
#  {nan},
#  "{'Current assets': nan, 'Cash at bank and in hand': '1000', 'Net assets': '1000', 'Issued share capital': nan, '1000 Ordinary Shares 1 of Â£ each': '1000', 'Total Shareholder funds': '1000'}",
#  "{'Called up share capital not paid': '1000', 'Current Assets': '4240', 'Creditors: amounts falling due within one year': '-3082', 'Net current assets (liabilities)': '1158', 'Total assets less current liabilities': '2158', 'Total net assets (liabilities)': '2158', 'Capital and reserves': '2158'}",
#  "{'Called up share capital not paid': nan, 'Fixed Assets': '1', 'Current Assets': '254', 'Prepayments and accrued income': nan, 'Creditors: amounts falling due within one year': '0', 'Net current assets (liabilities)': '254', 'Total assets less current liabilities': '255', 'Creditors: amounts falling due after more than one year': '0', 'Provisions for liabilities': '0', 'Accruals and deferred income': '0', 'Total net assets (liabilities)': '255', 'Capital and reserves': '255'}",
#  "{'Current assets': nan, 'Cash at bank and in hand': '2', 'Net assets': '2', 'Issued share capital': nan, '2': '2', 'Total Shareholder funds': '2'}",
#  "{'Called up share capital not paid': '1', 'Fixed Assets': '18812', 'Current Assets': '87198', 'Creditors: amounts falling due within one year': '-151460', 'Net current assets (liabilities)': '-64262', 'Total assets less current liabilities': '-45449', 'Total net assets (liabilities)': '-45449', 'Capital and reserves': '-45449'}",
#  {nan},
#  "{'Called up share capital not paid': '2', 'Net assets': '2', 'Tssued share capital': nan, '2 Ordinary Shares 1 of Â£ each': '2', 'Total Shareholder funds': '2'}",
#  "{'Current assets': nan, 'Cash at bank and in hand': '1', 'Net assets': '1', 'Issued share capital': nan, '1 Ordinary Share 1 of Â£ each': '1', 'Total Shareholder funds': '1'}",
#  "{'Current Assets': '5751', 'Net current assets (liabilities)': '5751', 'Total assets less current liabilities': '5751', 'Creditors: amounts falling due after more than one': nan, '2.,531)': '-2.531', 'year': nan, 'Total net assets (liabilities)': '3220', 'Capital and reserves': '3220'}",
#  "{'Current Assets': '8312', 'Creditors: amounts falling due within one year': '-5606', 'Net current assets (liabilities)': '2706', 'Total assets less current liabilities': '2706', 'Total net assets (liabilities)': '2706', 'Capital and reserves': '2706'}",
#  "{'Called up share capital not paid': '100', 'Net assets': '100', 'Tssued share capital': nan, '100 Ordinary Shares of Â£ | each': '100', 'Total Shareholder funds': '100'}",
#  "{'Current assets': nan, 'Cash at bank and in hand': '100', 'Net assets': '100', 'Issued share capital': nan, '100 A Shares 1 of Â£ each': '100', 'Total Shareholder funds': '100'}",
#  {nan},
#  "{'Fixed Assets': nan, 'Current Assets': nan, 'Creditors: amounts falling due within one year': '0', 'Net current assets (liabilities)': '0', 'Total assets less current liabilities': '0', 'Creditors: amounts falling due after more than one year': '0', 'Total net assets (liabilities)': '0', 'Capital and reserves': '0'}",
#  "{'Called up share capital not paid': '100', 'Net assets': '100', 'Tssued share capital': nan, '100 Ordinary Shares 1 of Â£ each': '100', 'Total Shareholder funds': '100'}",
#  "{'Current assets': nan, 'Cash at bank and in hand': '1', 'Net assets': '1', 'Issued share capital': nan, '1 Ordinary Share 1 of Â£ each': '1', 'Total Shareholder funds': '1'}",
#  "{'Called up share capital not paid': nan, 'Fixed Assets': nan, 'Current Assets': '500000', 'Prepayments and accrued income': nan, 'Net current assets (liabilities)': '500000', 'Total assets less current liabilities': '500000', 'Total net assets (liabilities)': '500000', 'Capital and reserves': '500000'}",
#  "{'Fixed assets': '578', 'Current assets': '112532', 'Creditors: amounts falling due within one year': '-21596', 'Net current assets': '90936', 'Total assets less current liabilities': '91514', 'Accruals and deferred income': '-3850', 'Net assets': '87604', 'Capital and reserves': '87664'}",
#  "{'Called up share capital not paid': '0.00', 'Current assets': nan, 'Cash at bank and in hand': '100.00', 'Net assets': '100.00', 'Issued share capital': nan, '100 Ordinary Shares of Â£1.00 each': '100.00', 'Total Shareholder funds': '100.00'}",
#  "{'Called up share capital not paid': nan, 'Fixed Assets': '780', 'Current Assets': '2942', 'Creditors: amounts falling due within one year': '-5690', 'Net current assets (liabilities)': '-2748', 'Total assets less current liabilities': '-1968', 'Total net assets (liabilities)': '-1968', 'Capital and reserves': '-1968'}",
#  "{'Called up share capital not paid': '5', 'Fixed Assets': nan, 'Current Assets': nan, 'Prepayments and accrued income': nan, 'Creditors: amounts falling due within one year': '0', 'Net current assets (liabilities)': '0', 'Total assets less current liabilities': '5', 'Creditors: amounts falling due after more than one year': '0', 'Provisions for liabilities': '0', 'Accruals and deferred income': '0', 'Total net assets (liabilities)': '5', 'Capital and reserves': '5'}",
#  "{'Net assets': '0', 'Reserves': '0'}",
#  "{'Called up share capital not paid': '1', 'Current Assets': '1016', 'Net current assets (liabilities)': '1016', 'Total assets less current liabilities': '1017', 'Total net assets (liabilities)': '1017', 'Capital and reserves': '1017'}",
#  "{'Current assets': nan, 'Cash at bank and in hand': '100', 'Net assets': '100', 'Issued share capital': nan, '100 Ordinary Shares of Â£ | each': '100', 'Total Shareholder funds': '100'}",
#  "{'Current assets': nan, 'Cash at bank and in hand': '100', 'Net assets': '100', 'Issued share capital': nan, '100 Ordinary Shares 1 of Â£ each': '100', 'Total Shareholder funds': '100'}",
#  "{'Current assets': nan, 'Cash at bank and in hand': '1', 'Net assets': '1', 'Issued share capital': nan, '1 Ordinary Share 1 of Â£ each': '1', 'Total Shareholder funds': '1'}",
#  "{'Called up share capital not paid': nan, 'Fixed Assets': nan, 'Current Assets': nan, 'Net current assets (liabilities)': '0', 'Total assets less current liabilities': '0', 'Total net assets (liabilities)': '0', 'Capital and reserves': '0'}",
#  "{'Current assets': nan, 'Cash at bank and in hand': '1', 'Net assets': '1', 'Issued share capital': nan, '1 Ordinary Share 1 of Â£ each': '1', 'Total Shareholder funds': '11'}",
#  "{'Called up share capital not paid': '100', 'Net assets': '100', 'Tssued share capital': nan, '1 Ordinary Share of Â£ 100 each': '100', 'Total Shareholder funds': '100'}",
#  "{'Fixed assets': '13251', 'Current assets': '4182', 'Creditors: amounts falling due within': nan, 'one year': '2463', 'Net current assets': '6645', 'Total assets less current liabilities': '19896', 'Creditors: amounts falling due after': nan, 'more than one year': '-3779', 'Accruals and deferred income': '-450', 'Net assets': '15667', 'Capital and reserves': '15667'}",
#  "{'Current Assets': '2386', 'Creditors: amounts falling due within one year': '-360', 'Net current assets (liabilities)': '2026', 'Total assets less current liabilities': '2026', 'Total net assets (liabilities)': '2026', 'Capital and reserves': '2026'}",
#  "{'Current assets': nan, 'Cash at bank and in hand': '5', 'Net assets': '5', 'Issued share capital': nan, '5 Ordinary Shares 1 of Â£ each': '5', 'Total Shareholder funds': '5'}",
#  "{'Fixed Assets': '2456', 'Current Assets': '212740', 'Creditors: amounts falling due within one year': '-65764', 'Net current assets (liabilities)': '146976', 'Total assets less current liabilities': '149432', 'Provisions for liabilities': '-467', 'Total net assets (liabilities)': '148965', 'Capital and reserves': '148965'}",
#  "{'Called up share capital not paid': '1', 'Net assets': '1', 'Tssued share capital': nan, '1 Ordinary Share 1 of Â£ each': '1', 'Total Shareholder funds': '1'}",
#  "{'Called up share capital not paid': '200', 'Net assets': '200', 'Tssued share capital': nan, '200 Ordinary Shares 1 of Â£ each': '200', 'Total Shareholder funds': '200'}",
#  "{'Fixed assets': '12000', 'Current assets': '2191', 'Creditors: amounts falling due within': nan, 'one year': '-16080', 'Net current liabilities': '-13889', 'Total assets less current liabilities': '-1889', 'Creditors: amounts falling due after': nan, 'more than one year': '-6200', 'Net liabilities': '-8089', 'Capital and reserves': '-8089'}",
#  "{'Called up share capital not paid': '1', 'Net assets': '1', 'Tssued share capital': nan, '1 Ordinary Share 1 of Â£ each': '1', 'Total Shareholder funds': '1'}",
#  "{'Current assets': nan, 'Cash at bank and in hand': '1', 'Net assets': '1', 'Issued share capital': nan, '1 Ordinary Share 1 of Â£ each': '1', 'Total Shareholder funds': '1'}",
#  "{'Net assets': '0', 'Reserves': '0'}",
#  "{'Called up share capital not paid': '100', 'Net assets': '100', 'Tssued share capital': nan, '100 Ordinary Shares of Â£ | each': '100', 'Total Shareholder funds': '100'}",
#  "{'Called up share capital not paid': '4', 'Current Assets': '7078', 'Creditors: amounts falling due within one year': '-7047', 'Net current assets (liabilities)': '31', 'Total assets less current liabilities': '35', 'Total net assets (liabilities)': '35', 'Capital and reserves': '35'}",
#  "{'Current assets': nan, 'Cash at bank and in hand': '100', 'Net assets': '100', 'Issued share capital': nan, '100 Ordinary Shares 1 of Â£ each': '100', 'Total Shareholder funds': '100'}",
#  "{'Fixed Assets': '8460', 'Current Assets': '22756', 'Creditors: amounts falling due within one year': '-27702', 'Net current assets (liabilities)': '-4946', 'Total assets less current liabilities': '3514', 'Total net assets (liabilities)': '3514', 'Capital and reserves': '3514'}",
#  {nan},
#  "{'Current Assets': '196', 'Creditors: amounts falling due within one year': '-18', 'Net current assets (liabilities)': '178', 'Total assets less current liabilities': '178', 'Total net assets (liabilities)': '178', 'Capital and reserves': '178'}",
#  "{'Current assets': nan, 'Cash at bank and in hand': '50', 'Net assets': '50', 'Issued share capital': nan, '50 Preference Shares 1 of Â£ each': '50', 'Total Shareholder funds': '50'}",
#  {nan},
#  "{'Called up share capital not paid': '2', 'Net assets': '2', 'Tssued share capital': nan, '2 Ordinary Shares 1 of Â£ each': '2', 'Total Shareholder funds': '2'}",
#  "{'Called up share capital not paid': '1', 'Net assets': '1', 'Tssued share capital': nan, '1 Ordinary Share 1 of Â£ each': '1', 'Total Shareholder funds': '1'}",
#  "{'Fixed assets': '576', 'Current assets': '2020', 'Creditors: Amounts falling due within one year': '-8895', 'Net current liabilities': '-6.875', 'Total assets less current liabilities': '-6299', 'Accruals and deferred income': '-312', '(6,611)': '-5004', 'Capital and reserves': '-6611'}",
#  "{'Fixed Assets': '7264', 'Current Assets': '14291', 'Creditors: amounts falling due within one year': '-563', 'Net current assets (liabilities)': '13728', 'Total assets less current liabilities': '20992', 'Total net assets (liabilities)': '20992', 'Capital and reserves': '20992'}",
#  "{'Current Assets': '10000', 'Net current assets (liabilities)': '10000', 'Total assets less current liabilities': '10000', 'Total net assets (liabilities)': '10000', 'Capital and reserves': '10000'}",
#  "{'Called up share capital not paid': '100', 'Net assets': '100', 'Tssued share capital': nan, '100 A Shares 1 of Â£ each': '100', 'Total Shareholder funds': '100'}",
#  "{'Called up share capital not paid': '1', 'Net assets': '1', 'Tssued share capital': nan, '1 Ordinary Share 1 of Â£ each': '1', 'Total Shareholder funds': '1'}",
#  "{('Current assets', None): None, ('Cash at bank and in hand 2', ' -'): ' -', (None, None): None, ('Creditors: amounts falling', None): None, ('due within one year', '5'): ' -', ('Net current assets', ' -'): '-', ('Net assets', ' -'): '-', ('Capital and reserves', None): None}",
#  "{'Fixed Assets': '83750', 'Current Assets': '93152', 'Creditors: amounts falling due within one year': '-29819', 'Net current assets (liabilities)': '63333', 'Total assets less current liabilities': '147083', 'Creditors: amounts falling due after more than one': nan, '(37.070)': '-42.811', 'year': nan, 'Total net assets (liabilities)': '110013', 'Capital and reserves': '110013'}",
#  "{'Called up share capital not paid': '100', 'Net assets': '100', 'Tssued share capital': nan, '100': '100Shares1ofÂ£each', 'Total Shareholder funds': '___100'}",
#  "{'Called up share capital not paid': nan, 'Fixed Assets': nan, 'Current Assets': nan, 'Prepayments and accrued income': nan, 'Creditors: amounts falling due within one year': '0', 'Net current assets (liabilities)': '0', 'Total assets less current liabilities': '0', 'Creditors: amounts falling due after more than one year': '0', 'Provisions for liabilities': '0', 'Accruals and deferred income': '0', 'Total net assets (liabilities)': '0', 'Capital and reserves': '0'}",
#  "{'Current Assets': '22560', 'Creditors: amounts falling due within one year': '-2038', 'Net current assets (liabilities)': '20522', 'Total assets less current liabilities': '20522', 'Total net assets (liabilities)': '20522', 'Capital and reserves': '20522'}",
#  "{'Current assets': nan, 'Cash at bank and in hand': '1', 'Net assets': '1', 'Issued share capital': nan, '1 Ordinary Share 1 of Â£ each': '1', 'Total Shareholder funds': '1'}",
#  "{'Fixed Assets': '46754', 'Current Assets': '8017', 'Creditors: amounts falling due within one year': '-65151', 'Net current assets (liabilities)': '-57134', 'Total assets less current liabilities': '-10380', 'Provisions for liabilities': '-7458', 'Accruals and deferred income': '-1200', 'Total net assets (liabilities)': '-19038', 'Capital and reserves': '-19038'}",
#  "{'Fixed Assets': '8326', 'Current Assets': '17380', 'Creditors: amounts falling due within one year': '-23723', 'Net current assets (liabilities)': '-6343', 'Total assets less current liabilities': '1983', 'Total net assets (liabilities)': '1983', 'Capital and reserves': '1983'}",
#  "{'Fixed Assets': '25000', 'Current Assets': nan, 'Net current assets (liabilities)': '0', 'Total assets less current liabilities': '25000', 'Creditors: amounts falling due after more than one': nan, '(24.998)': nan, 'year': nan, 'Total net assets (liabilities)': '2', 'Capital and reserves': '2'}",
#  "{'Called up share capital not paid': nan, 'Fixed Assets': nan, 'Current Assets': '24404', 'Creditors: amounts falling due within one year': '-26602', 'Net current assets (liabilities)': '-2198', 'Total assets less current liabilities': '-2198', 'Creditors: amounts falling due after more than one year': '0', 'Provisions for liabilities': '0', 'Accruals and deferred income': '0', 'Total net assets (liabilities)': '-2198', 'Capital and reserves': '-2198'}",
#  "{'Fixed Assets': '960', 'Current Assets': '1541', 'Creditors: amounts falling due within one year': '-1209', 'Net current assets (liabilities)': '332', 'Total assets less current liabilities': '1292', 'Total net assets (liabilities)': '1292', 'Capital and reserves': '1292'}",
#  "{'Current assets': '5527', 'Creditors: amounts falling due within one year': '-4247', 'Net current assets': '1280', 'Total assets less current liabilities': '1280', 'Accruals and deferred income': '-1273', 'Net assets': '7', 'Capital and reserves': '7'}",
#  "{'Called up share capital not paid': '2', 'Net assets': '2', 'Tssued share capital': nan, '2 Ordinary Shares 1 of Â£ each': '2', 'Total Shareholder funds': '2'}",
#  "{'Current assets': nan, 'Cash at bank and in hand': '20', 'Net assets': '20', 'Issued share capital': nan, '20 Ordinary Shares 1 of Â£ each': '20', 'Total Shareholder funds': '20'}",
#  "{'Current assets': nan, 'Cash at bank and in hand': '12', 'Net assets': '12', 'Issued share capital': nan, '12 Ordinary Shares 1 of Â£ each': '12', 'Total Shareholder funds': '12'}",
#  "{'Called up share capital not paid': '1', 'Net assets': '1', 'Tssued share capital': nan, '1 Ordinary Share 1 of Â£ each': '1', 'Total Shareholder funds': '11'}",
#  "{'Called up share capital not paid': '2', 'Net assets': '2', 'Tssued share capital': nan, '2 Ordinary Shares 1 of Â£ each': '2', 'Total Shareholder funds': '2'}",
#  "{'Current assets': nan, 'Cash at bank and in hand': '3', 'Net assets': '3', 'Issued share capital': nan, '3 Ordinary Shares 1 of Â£ each': '33', 'Total Shareholder funds': '33'}",
#  "{'Called up share capital not paid': '100', 'Net assets': '100', 'Tssued share capital': nan, '100 Ordinary Shares 1 of Â£ each': '100', 'Total Shareholder funds': '100'}",
#  {nan},
#  "{'Called up share capital not paid': '6', 'Net assets': '6', 'Tssued share capital': nan, '6 Ordinary Shares 1 of Â£ each': '6', 'Total Shareholder funds': '6'}",
#  "{'Current Assets': '52167', 'Creditors: amounts falling due within one year': '-16402', 'Net current assets (liabilities)': '35765', 'Total assets less current liabilities': '35765', 'Total net assets (liabilities)': '35765', 'Capital and reserves': '35765'}",
#  "{'Fixed Assets': '2046', 'Current Assets': '53790', 'Creditors: amounts falling due within one year': '-23146', 'Net current assets (liabilities)': '30644', 'Total assets less current liabilities': '32690', 'Total net assets (liabilities)': '32690', 'Capital and reserves': '32690'}",
#  "{'Fixed Assets': '14800', 'Current Assets': '570', 'Net current assets (liabilities)': '570', 'Total assets less current liabilities': '15370', 'Creditors: amounts falling due after more than one year': '-18659', 'Total net assets (liabilities)': '-3289', 'Capital and reserves': '-3289'}",
#  "{'Fixed Assets': '3650', 'Current Assets': '7721', 'Creditors: amounts falling due within one year': '-8776', 'Net current assets (liabilities)': '-1055', 'Total assets less current liabilities': '2595', 'Total net assets (liabilities)': '2595', 'Capital and reserves': '2595'}",
#  "{'Called up share capital not paid': '100', 'Net assets': '100', 'Tssued share capital': nan, '100 Ordinary Shares 1 of Â£ each': '100', 'Total Shareholder funds': '100'}",
#  "{'Current Assets': '5609', 'Creditors: amounts falling due within one year': '-5392', 'Net current assets (liabilities)': '217', 'Total assets less current liabilities': '217', 'Total net assets (liabilities)': '217', 'Capital and reserves': '217'}",
#  "{'Current assets': nan, 'Cash at bank and in hand': '10', 'Net assets': '10', 'Issued share capital': nan, '1000 Ordinary Shares of Â£ 0.01 each': '10', 'Total Shareholder funds': '10'}",
#  "{'Called up share capital not paid': nan, 'Fixed Assets': '47942', 'Current Assets': '26316', 'Prepayments and accrued income': nan, 'Creditors: amounts falling due within one year': '-208648-121079', 'Net current assets (liabilities)': '-182332', 'Total assets less current liabilities': '-134390', 'Creditors: amounts falling due after more than one': nan, '0': '0', 'year': nan, 'Provisions for liabilities': '0', 'Accruals and deferred income': '0', 'Total net assets (liabilities)': '-134390', 'Capital and reserves': '-134390'}",
#  "{'Called up share capital not paid': '1', 'Net assets': '1', 'Tssued share capital': nan, '1 Ordinary Share 1 of Â£ each': '1', 'Total Shareholder funds': '1'}",
#  "{'Called up share capital not paid': '100', 'Net assets': '100', 'Tssued share capital': nan, '100 Ordinary Shares of Â£ | each': '100', 'Total Shareholder funds': '100'}",
#  "{'Fixed Assets': '931', 'Current Assets': '2145', 'Creditors: amounts falling due within one year': '-2502', 'Net current assets (liabilities)': '-357', 'Total assets less current liabilities': '574', 'Total net assets (liabilities)': '574', 'Capital and reserves': '574'}",
#  "{'Called up share capital not paid': '0', 'Current assets': nan, 'Cash at bank and in hand': '100', 'Net assets': '100', 'Authorised share capital': nan, '100 ORDINARY SHARES of Â£1 each': '100', 'Issued share capital': nan, 'Total shareholder funds': '100', 'NOTES': nan, '1. During the year the company allotted 100 ordinary shares with an aggregate nominal value of Â£ 0, the': nan, 'consideration received by the company 0 was Â£': nan}",
#  "{'Current Assets': '284222', 'Creditors: amounts falling due within one year': '-28420', 'Net current assets (liabilities)': '2', 'Total assets less current liabilities': '2', 'Total net assets (liabilities)': '2', 'Capital and reserves': '2'}",
#  "{'Called up share capital not paid': '0', 'Current assets': nan, 'Cash at bank and in hand': '100', 'Net assets': '100', 'Authorised share capital': nan, '100 ORDINARY SHARES of Â£1 each': '100', 'Issued share capital': nan, 'Total shareholder funds': '100', 'NOTES': nan, '1. During the year the company allotted 100 ordinary shares with an aggregate nominal value of Â£ 0, the': nan, 'consideration received by the company 0 was Â£': nan}",
#  "{'Called up share capital not paid': '1', 'Net assets': '1', 'Tssued share capital': nan, '1 Ordinary Share 1 of Â£ each': '1', 'Total Shareholder funds': '1'}",
#  "{'Creditors: amounts falling due within one year': '-16666', 'Net current assets (liabilities)': '-16666', 'Total assets less current liabilities': '-16666', 'Total net assets (liabilities)': '-16666', 'Capital and reserves': '-16666'}",
#  {nan},
#  "{'Current assets': '198', 'Creditors: amounts falling due within': nan, 'one year': '3893', 'Net current assets': '4091', 'Total assets less current liabilities': '4091', 'Accruals and deferred income': '-1600', 'Net assets': '2491', 'Capital and reserves': '2491'}",
#  "{'Called up share capital not paid': '0', 'Current assets': nan, 'Cash at bank and in hand': '100', 'Net assets': '100', 'Authorised share capital': nan, '100 ORDINARY SHARES of Â£1 each': '100', 'Issued share capital': nan, 'Total shareholder funds': '100', 'NOTES': nan, '1. During the year the company allotted 100 ordinary shares with an aggregate nominal value of Â£ 0, the': nan, 'consideration received by the company 0 was Â£': nan}",
#  "{'Current assets': nan, 'Cash at bank and in hand': '1', 'Net assets': '1', 'Issued share capital': nan, '1 Ordinary Share 1 of Â£ each': '1', 'Total Shareholder funds': '1'}",
#  "{'Called up share capital not paid': '100', 'Net assets': '100', 'Tssued share capital': nan, '100 Ordinary Shares of Â£ | each': '100', 'Total Shareholder funds': '100'}",
#  "{'Current Assets': '199', 'Creditors: amounts falling due within one year': '-198', 'Net current assets (liabilities)': '1', 'Total assets less current liabilities': '1', 'Total net assets (liabilities)': '1', 'Capital and reserves': '1'}",
#  {nan},
#  "{'Fixed Assets': '1078', 'Total assets less current liabilities': '1078', 'Total net assets (liabilities)': '1078', 'Capital and reserves': '1078'}",
#  "{'Current Assets': '10', 'Net current assets (liabilities)': '10', 'Total assets less current liabilities': '10', 'Creditors: amounts falling due after more than one': nan, '(5.822)': nan, 'year': nan, 'Total net assets (liabilities)': '-5776', 'Capital and reserves': '-5776'}",
#  "{'Called up share capital not paid': nan, 'Fixed Assets': '470', 'Current Assets': '2000', 'Prepayments and accrued income': nan, 'Creditors: amounts falling due within one year': '0', 'Net current assets (liabilities)': '2000', 'Total assets less current liabilities': '2470', 'Creditors: amounts falling due after more than one year': '0', 'Provisions for liabilities': '0', 'Accruals and deferred income': '0', 'Total net assets (liabilities)': '2470', 'Capital and reserves': '2470'}",
#  "{'Current assets': nan, 'Cash at bank and in hand': '100', 'Net assets': '100', 'Issued share capital': nan, '100 Ordinary Shares 1 of Â£ each': '100', 'Total Shareholder funds': '100'}",
#  "{'Called up share capital not paid': nan, 'Fixed Assets': nan, 'Current Assets': '71', 'Prepayments and accrued income': nan, 'Creditors: amounts falling due within one year': '0', 'Net current assets (liabilities)': '770', 'Total assets less current liabilities': '770', 'Creditors: amounts falling due after more than one year': '0', 'Provisions for liabilities': '0', 'Accruals and deferred income': '0', 'Total net assets (liabilities)': '770', 'Capital and reserves': '770'}",
#  "{'Called up share capital not paid': '1', 'Fixed Assets': '3334', 'Current Assets': nan, 'Prepayments and accrued income': '419', 'Creditors: amounts falling due within one year': '0', 'Net current assets (liabilities)': '419', 'Total assets less current liabilities': '3754', 'Creditors: amounts falling due after more than one year': '-3754', 'Provisions for liabilities': '0', 'Accruals and deferred income': '0', 'Total net assets (liabilities)': '0', 'Capital and reserves': '0'}",
#  {nan},
#  "{'Called up share capital not paid': '1', 'Fixed Assets': '3334', 'Current Assets': nan, 'Prepayments and accrued income': '419', 'Creditors: amounts falling due within one year': '0', 'Net current assets (liabilities)': '419', 'Total assets less current liabilities': '3754', 'Creditors: amounts falling due after more than one year': '-3754', 'Provisions for liabilities': '0', 'Accruals and deferred income': '0', 'Total net assets (liabilities)': '0', 'Capital and reserves': '0'}",
#  "{'Current assets': nan, 'Cash at bank and in hand': '1', 'Net assets': '1', 'Issued share capital': nan, '1 Ordinary Share 1 of Â£ each': '1', 'Total Shareholder funds': '1'}",
#  "{'Current assets': nan, 'Cash at bank and in hand': '100', 'Net assets': '100', 'Issued share capital': nan, '100 Ordinary Shares 1 of Â£ each': '100', 'Total Shareholder funds': '100'}",
#  "{'Called up share capital not paid': '1', 'Net assets': '1', 'Tssued share capital': nan, '1 Ordinary Share 1 of Â£ each': '1', 'Total Shareholder funds': '1'}",
#  "{('Fixed assets', None): None, ('Tangible assets', ' 2'): ' 83', ('Current assets', None): None, ('Cash at bank and in hand', ' 22,639'): '9,456', ('Creditors: amounts falling due', None): None, ('within one year', ' 3'): ' (22,757)', ('Net current liabilities', '(118)'): '(29)', ('Net (liabilities)/assets', ' (35)'): ' 138', ('Capital and reserves', None): None}",
#  {nan},
#  "{'Current assets': nan, 'Cash at bank and in hand': '1', 'Net assets': '1', 'Issued share capital': nan, '1 Ordinary Share 1 of Â£ each': '1', 'Total Shareholder funds': '1'}",
#  "{'Current Assets': '3656', 'Creditors: amounts falling due within one year': '-3567', 'Net current assets (liabilities)': '89', 'Total assets less current liabilities': '89', 'Total net assets (liabilities)': '89', 'Capital and reserves': '89'}",
#  "{'Current Assets': '6160', 'Creditors: amounts falling due within one year': '-6028', 'Net current assets (liabilities)': '132', 'Total assets less current liabilities': '132', 'Total net assets (liabilities)': '132', 'Capital and reserves': '132'}",
#  "{'Current Assets': '677', 'Creditors: amounts falling due within one year': '31D', 'Net current assets (liabilities)': '366', 'Total assets less current liabilities': '366', 'Total net assets (liabilities)': '366', 'Capital and reserves': '366'}",
#  {nan},
#  "{'Called up share capital not paid': '1', 'Fixed Assets': '97', 'Current Assets': nan, 'Net current assets (liabilities)': '0', 'Total assets less current liabilities': '98', 'Total net assets (liabilities)': '98', 'Capital and reserves': '98'}",
#  "{'Called up share capital not paid': '3', 'Net assets': '3', 'Tssued share capital': nan, '3 Ordinary Shares 1 of Â£ each': '3', 'Total Shareholder funds': '3'}",
#  "{'Called up share capital not paid': '1', 'Net assets': '1', 'Tssued share capital': nan, '1 Ordinary Share 1 of Â£ each': '1', 'Total Shareholder funds': '1'}",
#  "{'Fixed Assets': '923', 'Current Assets': '4755', 'Creditors: amounts falling due within one year': '-1719', 'Net current assets (liabilities)': '3036', 'Total assets less current liabilities': '3959', 'Total net assets (liabilities)': '3959', 'Capital and reserves': '3959'}",
#  {nan},
#  "{'Fixed Assets': '923', 'Current Assets': '4755', 'Creditors: amounts falling due within one year': '-1719', 'Net current assets (liabilities)': '3036', 'Total assets less current liabilities': '3959', 'Total net assets (liabilities)': '3959', 'Capital and reserves': '3959'}",
#  "{'Current assets': nan, 'Cash at bank and in hand': '10', 'Net assets': '10', 'Issued share capital': nan, '10 Ordinary Shares 1 of Â£ each': '10', 'Total Shareholder funds': '10'}",
#  {nan},
#  "{'Current assets': nan, 'Cash at bank and in hand': '10', 'Net assets': '10', 'Issued share capital': nan, '10 Ordinary Shares 1 of Â£ each': '10', 'Total Shareholder funds': '10'}",
#  "{'Current assets': nan, 'Cash at bank and in hand': '1', 'Net assets': '1', 'Issued share capital': nan, '1 Ordinary Share 1 of Â£ each': '1', 'Total Shareholder funds': '11'}",
#  "{'Called up share capital not paid': '0', 'Current assets': nan, 'Cash at bank and in hand': '11', 'Net assets': '11', 'Issued share capital': nan, '11 Ordinary Shares of Â£ | each': '11', 'Total Shareholder funds': '11'}",
#  "{'Current Assets': '5383', 'Creditors: amounts falling due within one year': '-5054', 'Net current assets (liabilities)': '329', 'Total assets less current liabilities': '329', 'Creditors: amounts falling due after more than one year': '0', 'Total net assets (liabilities)': '329', 'Capital and reserves': '329'}",
#  "{'Fixed assets': '81626', 'Current assets': '106513', 'Creditors: amounts falling due within': nan, 'one year': '-124356', 'Net current liabilities': '-17843', 'Total assets less current liabilities': '63783', 'Creditors: amounts falling due after': nan, 'more than one year': '-63618', 'Net assets': '165', 'Capital and reserves': '165'}",
#  {nan},
#  "{'Called up share capital not paid': '2', 'Net assets': '2', 'Tssued share capital': nan, '2 Ordinary Shares 1 of Â£ each': '2', 'Total Shareholder funds': '2'}",
#  "{'Current Assets': '30432', 'Creditors: amounts falling due within one year': '-30213', 'Net current assets (liabilities)': '219', 'Total assets less current liabilities': '219', 'Total net assets (liabilities)': '219', 'Capital and reserves': '219'}",
#  "{'Called up share capital not paid': '1', 'Net assets': '1', 'Tssued share capital': nan, '1 Ordinary Share 1 of Â£ each': '1', 'Total Shareholder funds': '1'}",
#  "{'Current assets': nan, 'Cash at bank and in hand': '10000', '10,000': '10000', None: nan, 'Capital and reserves': nan}",
#  "{'Fixed Assets': '211', 'Current Assets': '795', 'Net current assets (liabilities)': '795', 'Total assets less current liabilities': '1006', 'Creditors: amounts falling due after more than one': nan, '(2,573)': '-1982', 'year': nan, 'Total net assets (liabilities)': '-1567', 'Capital and reserves': '-1567'}",
#  "{'Called up share capital not paid': '0', 'Current assets': nan, 'Cash at bank and in hand': '30', 'Net assets': '30', 'Authorised share capital': nan, '0 Ordinary of Â£1 each': nan, 'Issued share capital': nan, '30 Ordinary of Â£1 each': '30', 'Total shareholder funds': '30', 'NOTES': nan, '1. During the year the company allotted O ordinary shares with an aggregate nominal value of Â£ 0, the': nan, 'consideration received by the company 0 was Â£': nan}",
#  "{'Fixed assets': '21575', 'Creditors: amounts falling due within': nan, 'one year': '-22094', 'Net current liabilities': '-22094', 'Total assets less current liabilities': '-519', 'Net liabilities': '-519', 'Capital and reserves': '-519'}",
#  "{'Called up share capital not paid': '100', 'Current assets': '296', 'Creditors: amounts falling due within one year': '-1219', 'Net current liabilities': '-923', 'Total assets less current liabilities': '-823', 'Accruals and deferred income': '-80', 'Net liabilities': '-903', 'Capital and reserves': '-903'}",
#  "{'Called up share capital not paid': '1', 'Current assets': '5792', 'Creditors: amounts falling due within one year': '-5161', 'Net current assets': '631', 'Total assets less current liabilities': '632', 'Net assets': '632', 'Capital and reserves': '632'}",
#  "{'Called up share capital not paid': '2', 'Net assets': '2', 'Tssued share capital': nan, '2 Ordinary Shares 1 of Â£ each': '2', 'Total Shareholder funds': '2'}",
#  "{'Current assets': nan, 'Cash at bank and in hand': '100', 'Net assets': '100', 'Issued share capital': nan, '100 Ordinary Shares 1 of Â£ each': '100', 'Total Shareholder funds': '100'}",
#  "{'Called up share capital not paid': '0', 'Current assets': nan, 'Cash at bank and in hand': '100', 'Net assets': '100', 'Authorised share capital': nan, '0 Ordinary of Â£1 each': nan, 'Issued share capital': nan, '100 Ordinary of Â£1 each': '100', 'Total shareholder funds': '100', 'NOTES': nan, '1. During the year the company allotted O ordinary shares with an aggregate nominal value of Â£ 0, the': nan, 'consideration received by the company 0 was Â£': nan}",
#  "{'Called up share capital not paid': '98', 'Fixed Assets': '173395', 'Current Assets': '79129', 'Creditors: amounts falling due within one year': '-77245-118666', 'Net current assets (liabilities)': '1884', 'Total assets less current liabilities': '175377', 'Creditors: amounts falling due after more than one': nan, '(56)': nan, 'year': nan, 'Total net assets (liabilities)': '175321', 'Capital and reserves': '175321'}",
#  "{'Called up share capital not paid': '1', 'Net assets': '1', 'Tssued share capital': nan, '1 Ordinary Share 1 of Â£ each': '1', 'Total Shareholder funds': '1'}",
#  {nan},
#  "{'Net assets': '0', 'Reserves': '0'}",
#  "{'Current Assets': '233663', 'Creditors: amounts falling due within one year': '-37418', 'Net current assets (liabilities)': '196245', 'Total assets less current liabilities': '196245', 'Total net assets (liabilities)': '196245', 'Capital and reserves': '196245'}",
#  "{'Called up share capital not paid': '1', 'Net assets': '1', 'Tssued share capital': nan, '1 Ordinary Share 1 of Â£ each': '1', 'Total Shareholder funds': '1'}",
#  "{'Net assets': '0', 'Reserves': '0'}",
#  "{'Current assets': nan, 'Cash at bank and in hand': '1', 'Net assets': '1', 'Issued share capital': nan, '1 Ordinary Share 1 of Â£ each': '1', 'Total Shareholder funds': '1'}",
#  {nan},
#  "{'Called up share capital not paid': '1', 'Capital and reserves': '1'}",
#  "{'Fixed Assets': nan, 'Current Assets': '9', 'Net current assets (liabilities)': '9', 'Total assets less current liabilities': '9', 'Total net assets (liabilities)': '9', 'Capital and reserves': '9'}",
#  "{'Called up share capital not paid': '100', 'Fixed Assets': '41605', 'Current Assets': '81299', 'Net current assets (liabilities)': '81299', 'Total assets less current liabilities': '123004', 'Total net assets (liabilities)': '123004', 'Capital and reserves': '123004'}",
#  "{'Fixed Assets': '2408', 'Creditors: amounts falling due within one year': '-2398', 'Net current assets (liabilities)': '-2398', 'Total assets less current liabilities': '10', 'Total net assets (liabilities)': '10', 'Capital and reserves': '10'}",
#  "{'Current assets': nan, 'Cash at bank and in hand': '100', 'Net assets': '100', 'Issued share capital': nan, '100 Ordinary Shares 1 of Â£ each': '100', 'Total Shareholder funds': '100'}",
#  "{'Current assets': nan, 'Cash at bank and in hand': '10', 'Net assets': '10', 'Issued share capital': nan, '10 Ordinary Shares 1 of Â£ each': '10', 'Total Shareholder funds': '10'}",
#  "{'Current assets': nan, 'Cash at bank and in hand': '100', '100': nan, None: nan, 'Capital and reserves': nan}",
#  "{'Current assets': '100', 'Net current assets': '100', 'Capital and reserves': '100'}",
#  "{'Current Assets': '3', 'Creditors: amounts falling due within one year': '-646', 'Net current assets (liabilities)': '-643', 'Total assets less current liabilities': '-643', 'Total net assets (liabilities)': '-643', 'Capital and reserves': '-643'}",
#  "{'Current assets': nan, 'Cash at bank and in hand': '2', 'Net assets': '2', 'Issued share capital': nan, '2 Ordinary Shares 1 of Â£ each': '2', 'Total Shareholder funds': '2'}",
#  "{'Called up share capital not paid': nan, 'Fixed Assets': '3942', 'Current Assets': nan, 'Prepayments and accrued income': nan, 'Creditors: amounts falling due within one year': '0', 'Net current assets (liabilities)': '0', 'Total assets less current liabilities': '3942', 'Creditors: amounts falling due after more than one year': '0', 'Provisions for liabilities': '0', 'Accruals and deferred income': '0', 'Total net assets (liabilities)': '3942', 'Capital and reserves': '3942'}",
#  "{'Called up share capital not paid': '10000', 'Net assets': '10000', 'Tssued share capital': nan, '10000 Ordinary Shares 1 of Â£ each': '10000', 'Total Shareholder funds': '10000'}",
#  "{'Called up share capital not paid': '100', 'Net assets': '100', 'Tssued share capital': nan, '100 Ordinary Shares of Â£ | each': '100', 'Total Shareholder funds': '100'}",
#  "{'Current assets': nan, 'Cash at bank and in hand': '1', 'Net assets': '1', 'Issued share capital': nan, '1 Ordinary Share 1 of Â£ each': '1', 'Total Shareholder funds': '1'}",
#  "{'Fixed Assets': '373', 'Current Assets': '45379', 'Creditors: amounts falling due within one year': '-14.435', 'Net current assets (liabilities)': '30944', 'Total assets less current liabilities': '31317', 'Total net assets (liabilities)': '31317', 'Capital and reserves': '31317'}",
#  "{'Called up share capital not paid': '0', 'Current assets': nan, 'Cash at bank and in hand': '1', 'Net assets': '1', 'Authorised share capital': nan, '0 Ordinary of Â£0 each': nan, 'Issued share capital': nan, '10 Ordinary of Â£0 each': '1', 'Total shareholder funds': '1', 'NOTES': nan, '1. During the year the company allotted 10 ordinary shares with an aggregate nominal value of Â£ 1, the': nan, 'consideration received by the company 1 was Â£': nan}",
#  "{'Fixed Assets': '286179', 'Current Assets': '53641', 'Creditors: amounts falling due within one year': '-267340-260257', 'Net current assets (liabilities)': '-213699-203603', 'Total assets less current liabilities': '72480', 'Creditors: amounts falling due after more than one': nan, '(54.155)': '-57.619', 'year': nan, 'Total net assets (liabilities)': '18325', 'Capital and reserves': '18325'}",
#  "{'Fixed Assets': '1522', 'Current Assets': '21449', 'Creditors: amounts falling due within one year': '-22532', 'Net current assets (liabilities)': '-1083', 'Total assets less current liabilities': '439', 'Total net assets (liabilities)': '439', 'Capital and reserves': '439'}",
#  "{'Fixed Assets': '9920', 'Current Assets': '21864', 'Creditors: amounts falling due within one year': '-16724', 'Net current assets (liabilities)': '5140', 'Total assets less current liabilities': '15060', 'Total net assets (liabilities)': '15060', 'Capital and reserves': '15060'}",
#  "{'Creditors: amounts falling due within one year': '-5374', 'Net current assets (liabilities)': '-5374', 'Total assets less current liabilities': '-5374', 'Total net assets (liabilities)': '-5374', 'Capital and reserves': '-5374'}",
#  "{'Current assets': nan, 'Cash at bank and in hand': '37', 'Net assets': '37', 'Issued share capital': nan, '37 Ordinary Shares 1 of Â£ each': '37', 'Total Shareholder funds': '37'}",
#  "{'Current assets': '18346', 'Creditors: amounts falling due within': nan, 'one year': '-15708', 'Net current assets': '2640', 'Total assets less current liabilities': '2640', 'Accruals and deferred income': '-1683', 'Net assets': '957', 'Capital and reserves': '957'}",
#  "{'Current assets': nan, 'Cash at bank and in hand': '100', 'Net assets': '100', 'Issued share capital': nan, '100 Ordinary Shares 1 of Â£ each': '100', 'Total Shareholder funds': '100'}",
#  {nan},
#  "{'Fixed Assets': '18099', 'Current Assets': '609', 'Creditors: amounts falling due within one year': '-23896', 'Net current assets (liabilities)': '-23287', 'Total assets less current liabilities': '-5188', 'Total net assets (liabilities)': '-5188', 'Capital and reserves': '-5188'}",
#  "{'Called up share capital not paid': nan, 'Fixed Assets': '279290', 'Current Assets': '2823', 'Prepayments and accrued income': '600', 'Creditors: amounts falling due within one year': '0', 'Net current assets (liabilities)': '3423', 'Total assets less current liabilities': '282713', 'Creditors: amounts falling due after more than one': nan, '(250,000) (256,000)': nan, 'year': nan, 'Total net assets (liabilities)': '32713', 'Capital and reserves': '32713'}",
#  "{'Current assets': nan, 'Cash at bank and in hand': '100', 'Net assets': '100', 'Issued share capital': nan, '100 Ordinary Shares of Â£ | each': '100', 'Total Shareholder funds': '100'}",
#  "{'Fixed Assets': '245', 'Current Assets': '18448', 'Creditors: amounts falling due within one year': '977', 'Net current assets (liabilities)': '17471', 'Total assets less current liabilities': '17716', 'Total net assets (liabilities)': '17716', 'Capital and reserves': '17716'}",
#  "{'Called up share capital not paid': '10000', 'Net assets': '10000', 'Tssued share capital': nan, '10000 Ordinary Shares 1 of Â£ each': '10000', 'Total Shareholder funds': '10000'}",
#  "{'Net assets': '0', 'Issued share capital': nan, '1 Ordinary Share 0 of Â£ each': '0', 'Total Shareholder funds': '0'}",
#  "{'Current assets': nan, 'Cash at bank and in hand': '1000', 'Net assets': '1000', 'Issued share capital': nan, '1000 Ordinary Shares 1 of Â£ each': '1000', 'Total Shareholder funds': '1000'}",
#  "{'Fixed Assets': '15302', 'Current Assets': '8242', 'Creditors: amounts falling due within one year': '-9106', 'Net current assets (liabilities)': '-864', 'Total assets less current liabilities': '14438', 'Creditors: amounts falling due after more than one': nan, '(14415)': '-18.676', 'year': nan, 'Total net assets (liabilities)': '23', 'Capital and reserves': '23'}",
#  "{'Called up share capital not paid': '1', 'Net assets': '1', 'Tssued share capital': nan, '1 Ordinary Share 1 of Â£ each': '1', 'Total Shareholder funds': '1'}",
#  "{'Fixed assets': nan, 'Current assets': '29669', 'Prepayments and accrued income': '3360', '33,029': '24826', 'Creditors: amounts falling due within': nan, 'one year': '-22228', 'Net current assets': '10801', 'Total assets less current liabilities': '10801', 'Net assets': '10801', 'Capital and reserves': '10801'}",
#  {nan},
#  "{'Current Assets': '187', 'Creditors: amounts falling due within one year': '-9547', 'Net current assets (liabilities)': '-9360', 'Total assets less current liabilities': '-9360', 'Creditors: amounts falling due after more than one': nan, '-': '-7.359', 'year': nan, 'Total net assets (liabilities)': '-9360', 'Capital and reserves': '-9360'}",
#  {nan},
#  "{'Current assets': '61563', 'Creditors: amounts falling due within': nan, 'one year': '-55479', 'Net current assets': '6084', 'Total assets less current liabilities': '6084', 'Net assets': '6084', 'Capital and reserves': '6084'}",
#  "{'Fixed Assets': '9310', 'Current Assets': '116772', 'Creditors: amounts falling due within one year': '-54731', 'Net current assets (liabilities)': '62041', 'Total assets less current liabilities': '71351', 'Total net assets (liabilities)': '71351', 'Capital and reserves': '71351'}",
#  "{'Fixed Assets': '3', 'Current Assets': '13787', 'Creditors: amounts falling due within one year': '-14360', 'Net current assets (liabilities)': '-573', 'Total assets less current liabilities': '-570', 'Total net assets (liabilities)': '-570', 'Capital and reserves': '579'}",
#  "{'Called up share capital not paid': '1', 'Net assets': '1', 'Tssued share capital': nan, '1 Ordinary Share 1 of Â£ each': '1', 'Total Shareholder funds': '1'}",
#  "{'Fixed assets': '533', 'Current assets': '43465', 'Creditors: amounts falling due within one': nan, 'year': '-42885', 'Net current assets': '580', 'Total assets less current liabilities': '1113', 'Net assets': '1113', 'Capital and reserves': '1113'}",
#  "{'Called up share capital not paid': nan, 'Fixed Assets': nan, 'Current Assets': nan, 'Prepayments and accrued income': nan, 'Creditors: amounts falling due within one year': '0', 'Net current assets (liabilities)': '0', 'Total assets less current liabilities': '0', 'Creditors: amounts falling due after more than one year': '0', 'Provisions for liabilities': '0', 'Accruals and deferred income': '0', 'Total net assets (liabilities)': '0', 'Capital and reserves': '0'}",
#  {nan},
#  "{'Called up share capital not paid': nan, 'Fixed Assets': nan, 'Current Assets': nan, 'Prepayments and accrued income': nan, 'Creditors: amounts falling due within one year': '0', 'Net current assets (liabilities)': '0', 'Total assets less current liabilities': '0', 'Creditors: amounts falling due after more than one year': '0', 'Provisions for liabilities': '0', 'Accruals and deferred income': '0', 'Total net assets (liabilities)': '0', 'Capital and reserves': '0'}",
#  "{'Current assets': nan, 'Cash at bank and in hand': '2', 'Net assets': '2', 'Issued share capital': nan, '2 Ordinary Shares 1 of Â£ each': '22', 'Total Shareholder funds': '22'}",
#  "{'Called up share capital not paid': nan, 'Fixed Assets': '20766', 'Current Assets': nan, 'Prepayments and accrued income': nan, 'Creditors: amounts falling due within one year': '0', 'Net current assets (liabilities)': '0', 'Total assets less current liabilities': '20766', 'Creditors: amounts falling due after more than one year': '0', 'Provisions for liabilities': '0', 'Accruals and deferred income': '0', 'Total net assets (liabilities)': '20766', 'Capital and reserves': '20766'}",
#  "{'Called up share capital not paid': '10', 'Net assets': '10', 'Tssued share capital': nan, '10 Ordinary Shares of Â£ | each': '10', 'Total Shareholder funds': '10'}",
#  "{'Current asscts': '3001', 'Creditors: amounts falling due within one year': '1196', 'Net current assets': '1805', 'Total assets less current liabilities': '1805', 'Accruals and deferred income': '360', '1,445': '856', 'Capital and reserves': '1445'}",
#  "{'Called up share capital not paid': '1', 'Net assets': '1', 'Tssued share capital': nan, '1 Ordinary Share 1 of Â£ each': '1', 'Total Shareholder funds': '1'}",
# ...
#  "{'Current assets': nan, 'Cash at bank and in hand': '100', 'Net assets': '100', 'Issued share capital': nan, '100 Ordinary Shares 1 of Â£ each': '100', 'Total Shareholder funds': '100'}",
#  "{'Current assets': nan, 'Cash at bank and in hand': '100', 'Net assets': '100', 'Issued share capital': nan, '100 ORDINARY Shares 1 of Â£ each': '100', 'Total Shareholder funds': '100'}",
#  "{'Called up share capital not paid': '0', 'Current assets': nan, 'Cash at bank and in hand': '100', 'Net assets': '100', 'Authorised share capital': nan, '0 Ordinary of Â£1 each': nan, 'Issued share capital': nan, '100 Ordinary of Â£1 each': '100', 'Total shareholder funds': '100', 'NOTES': nan, '1. During the year the company allotted O ordinary shares with an aggregate nominal value of Â£ 0, the': nan, 'consideration received by the company 0 was Â£': nan}",
#  "{'Current assets': nan, 'Cash at bank and in hand': '1', 'Net assets': '1', 'Issued share capital': nan, '1 Ordinary Share 1 of Â£ each': '1', 'Total Shareholder funds': '11'}",
#  "{'Current assets': nan, 'Cash at bank and in hand': '1', 'Net assets': '1', 'Issued share capital': nan, '1 Ordinary Share 1 of Â£ each': '1', 'Total Shareholder funds': '1'}",
#  "{'Fixed assets': '844', 'Current assets': '31979', 'Creditors: amounts falling due within': nan, 'one year': '-20019', 'Net current assets': '11960', 'Total assets less current liabilities': '12804', 'Accruals and deferred income': '-540', 'Net assets': '12264', 'Capital and reserves': '12264'}",
#  "{'Current assets': nan, 'Cash at bank and in hand': '100', 'Net assets': '100', 'Issued share capital': nan, '100 Ordinary Shares 1 of Â£ each': '100', 'Total Shareholder funds': '100'}",
#  "{'Current assets': nan, 'Cash at bank and in hand': '1', 'Net assets': '1', 'Issued share capital': nan, '1 Ordinary Share 1 of Â£ each': nan, 'Total Shareholder funds': nan}",
#  "{'Fixed Assets': nan, 'Current Assets': '25982', 'Creditors: amounts falling due within one year': '-25637', 'Net current assets (liabilities)': '345', 'Total assets less current liabilities': '345', 'Total net assets (liabilities)': '345', 'Capital and reserves': '345'}",
#  "{'Current Assets': '100', 'Net current assets (liabilities)': '100', 'Total assets less current liabilities': '100', 'Total net assets (liabilities)': '100', 'Capital and reserves': '100'}",
#  "{'Current assets': '2436', 'Creditors: amounts falling due within one': nan, 'year': '-3747', 'Net current (liabilities)/assets': '-1311', 'Total assets less current liabilities': '-1311', 'Net (liabilities)/assets': '-1311', 'Capital and reserves': '-1311'}",
#  "{'Current Assets': '34045', 'Creditors: amounts falling due within one year': '-32070', 'Net current assets (liabilities)': '1975', 'Total assets less current liabilities': '1975', 'Total net assets (liabilities)': '1975', 'Capital and reserves': '1975'}",
#  "{'Current assets': nan, 'Cash at bank and in hand': '1', 'Net assets': '1', 'Issued share capital': nan, '1 Ordinary Share 1 of Â£ each': '1', 'Total Shareholder funds': nan}",
#  {nan},
#  "{'Current Assets': '3514', 'Creditors: amounts falling due within one year': '-10516', 'Net current assets (liabilities)': '-7002', 'Total assets less current liabilities': '-7002', 'Total net assets (liabilities)': '-7002', 'Capital and reserves': '-7002'}",
#  "{'Current assets': nan, 'Cash at bank and in hand': '96', 'Net assets': '96', 'Issued share capital': nan, '96 Ordinary Shares 1 of Â£ each': '96', 'Total Shareholder funds': '96'}",
#  "{'Current assets': '1307', 'Creditors: amounts falling due within one year': '{6130', 'Net current (liabilities)/assets': '-4823', 'Net (liabilitiesÅ‚assets': '-4823', 'Capital and reserves': '-4823'}",
#  "{'Fixed assets': '1332', 'Current assets': '9242', 'Creditors: amounts falling due within': nan, 'one year': '-10551', 'Net current liabilities': '-1309', 'Total assets less current liabilities': '23', 'Creditors: amounts falling due after': nan, 'more than one year': nan, 'Net assets': '23', 'Capital and reserves': '23'}",
#  "{'Called up share capital not paid': '1', 'Net assets': '1', 'Tssued share capital': nan, '1 Ordinary Share 1 of Â£ each': '1', 'Total Shareholder funds': '1'}",
#  {nan},
#  "{'Current assets': nan, 'Cash at bank and in hand': '2', 'Net assets': '2', 'Issued share capital': nan, '2 Ordinary Shares 1 of Â£ each': '2', 'Total Shareholder funds': '2'}",
#  "{'Current Assets': '8278', 'Prepayments and accrued income': '1', 'Creditors: amounts falling due within one year': '-8212', 'Net current assets (liabilities)': '67', 'Total assets less current liabilities': '67', 'Total net assets (liabilities)': '67', 'Capital and reserves': '67'}",
#  "{'Current assets': nan, 'Cash at bank and in hand': '2', 'Net assets': '2', 'Issued share capital': nan, '2 Ordinary Shares 1 of Â£ each': '2', 'Total Shareholder funds': '2'}",
#  "{'Current assets': nan, 'Cash at bank and in hand': '100', 'Net assets': '100', 'Issued share capital': nan, '100 Ordinary Shares 1 of Â£ each': '100', 'Total Shareholder funds': '100'}",
#  "{'Current assets': nan, 'Cash at bank and in hand': '1', 'Net assets': '1', 'Issued share capital': nan, '1 Ordinary Share 1 of Â£ each': '1', 'Total Shareholder funds': '11'}",
#  "{'Called up share capital not paid': '2', 'Net assets': '2', 'Tssued share capital': nan, '2 Ordinary Shares 1 of Â£ each': '2', 'Total Shareholder funds': '2'}",
#  "{'Current Assets': '228', 'Creditors: amounts falling due within one year': '199', 'Net current assets (liabilities)': '29', 'Total assets less current liabilities': '29', 'Total net assets (liabilities)': '29', 'Capital and reserves': '29'}",
#  {nan},
#  "{'Current assets': nan, 'Cash at bank and in hand': '1', 'Net assets': '1', 'Issued share capital': nan, '1 Ordinary Share 1 of Â£ each': '1', 'Total Shareholder funds': '1'}",
#  "{'Current assets': '8', 'Net current assets': '8', 'Total assets less current liabilities': '8', 'Net assets': '8', 'Capital and reserves': '8'}",
#  "{'Fixed Assets': '49314', 'Current Assets': '14303', 'Net current assets (liabilities)': '14303', 'Total assets less current liabilities': '63617', 'Creditors: amounts falling due after more than one': nan, '(21478)': '-11.397', 'year': nan, 'Provisions for liabilities': '-51221', 'Accruals and deferred income': '-900', 'Total net assets (liabilities)': '-9982', 'Capital and reserves': '-9982'}",
#  "{'Current assets': nan, 'Cash at bank and in hand': '1', 'Net assets': '1', 'Issued share capital': nan, '1 Ordinary Share 1 of Â£ each': '1', 'Total Shareholder funds': '1'}",
#  "{'Fixed Assets': '325705', 'Current Assets': '209051', 'Creditors: amounts falling due within one year': '-281290', 'Net current assets (liabilities)': '-72239', 'Total assets less current liabilities': '253466', 'Total net assets (liabilities)': '253466', 'Capital and reserves': '253466'}",
#  "{'Fixed Assets': '2844', 'Current Assets': '11230', 'Creditors: amounts falling due within one year': '-13192', 'Net current assets (liabilities)': '-1962', 'Total assets less current liabilities': '882', 'Total net assets (liabilities)': '882', 'Capital and reserves': '882'}",
#  "{'Net assets': '0', 'Reserves': '0'}",
#  "{'Current assets': nan, 'Cash at bank and in hand': '1', 'Net assets': '1', 'Issued share capital': nan, '1 Ordinary Share 1 of Â£ each': '1', 'Total Shareholder funds': '1'}",
#  "{'Current assets': nan, 'Cash at bank and in hand': '100', 'Net assets': '100', 'Issued share capital': nan, '100 ordinary Shares 1 of Â£ each': '100', 'Total Shareholder funds': '100'}",
#  "{'Fixed Assets': '50398', 'Current Assets': '145751', 'Creditors: amounts falling due within one year': '-120686', 'Net current assets (liabilities)': '25065', 'Total assets less current liabilities': '75463', 'Creditors: amounts falling due after more than one': nan, '(14.282)': '0', 'year': nan, 'Total net assets (liabilities)': '61181', 'Capital and reserves': '61181'}",
#  "{'Called up share capital not paid': '0.00', 'Current assets': nan, 'Cash at bank and in hand': '1.00', 'Net assets': '1.00', 'Issued share capital': nan, '1 Ordinary Shares of Â£1.00 each': '1.00', 'Total Shareholder funds': '1.00'}",
#  "{'Current assets': nan, 'Cash at bank and in hand': '1', 'Net assets': '1', 'Issued share capital': nan, '1 Ordinary Share 1 of Â£ each': '1', 'Total Shareholder funds': '1'}",
#  "{'Called up share capital not paid': '2', 'Net assets': '2', 'Tssued share capital': nan, '2 Ordinary Shares 1 of Â£ each': '2', 'Total Shareholder funds': '2'}",
#  "{'Called up share capital not paid': '100', 'Net assets': '100', 'Tssued share capital': nan, '100 Ordinary Shares 1 of Â£ each': '100', 'Total Shareholder funds': '100'}",
#  "{'Current assets': nan, 'Cash at bank and in hand': '1', 'Net assets': '1', 'Issued share capital': nan, '1 Ordinary Share 1 of Â£ each': '1', 'Total Shareholder funds': '1'}",
#  {nan},
#  "{'Current assets': nan, 'Cash at bank and in hand': '0.01', 'Net assets': '0.01', 'Issued share capital': nan, '1 Ordinary Share of Â£ 0.01 each': '0.01', 'Total Shareholder funds': '0.01'}",
#  "{'Called up share capital not paid': '2', 'Net assets': '2', 'Tssued share capital': nan, '2 Ordinary Shares 1 of Â£ each': '22', 'Total Shareholder funds': '2z2'}",
#  "{'Called up share capital not paid': '2', 'Net assets': '2', 'Tssued share capital': nan, '2 Ordinary Shares 1 of Â£ each': '2', 'Total Shareholder funds': '2'}",
#  "{'Current assets': nan, 'Cash at bank and in hand': '1', 'Net assets': '1', 'Issued share capital': nan, '1 ORDINARY Share of Â£ | each': '1', 'Total Shareholder funds': '1'}",
#  "{'Current Assets': '1631', 'Creditors: amounts falling due within one year': '-984', 'Net current assets (liabilities)': '647', 'Total assets less current liabilities': '647', 'Creditors: amounts falling due after more than one year': nan, 'Total net assets (liabilities)': '647', 'Capital and reserves': '647'}",
#  "{'Fixed assets': '7976', 'Current assets': '19138', 'Prepayments and accrued income': nan, '17,324': nan, 'Creditors: amounts falling due': nan, 'within one year': '-21473', 'Net current liabilities': '-2335', 'Total assets less current liabilities': '5641', 'Accruals and deferred income': '-40', 'Net assets': '5601', 'Capital and reserves': '5601'}",
#  "{'Current Assets': '21293', 'Creditors: amounts falling due within one year': '-7897', 'Net current assets (liabilities)': '13396', 'Total assets less current liabilities': '13396', 'Total net assets (liabilities)': '13396', 'Capital and reserves': '13396'}",
#  "{'Current assets': nan, 'Cash at bank and in hand': '2', 'Net assets': '2', 'Issued share capital': nan, '2 Ordinary Shares 1 of Â£ each': '2', 'Total Shareholder funds': '2'}",
#  "{'Called up share capital not paid': '63', 'Net assets': '63', 'Tssued share capital': nan, '63 Ordinary Shares of Â£ | each': '63', 'Total Shareholder funds': '63'}",
#  "{'Current Assets': '31263', 'Creditors: amounts falling due within one year': '-24054', 'Net current assets (liabilities)': '7209', 'Total assets less current liabilities': '7209', 'Total net assets (liabilities)': '7209', 'Capital and reserves': '7209'}",
#  "{'Called up share capital not paid': '100', 'Net assets': '100', 'Tssued share capital': nan, '100 Ordinary Shares 1 of Â£ each': '100', 'Total Shareholder funds': '100'}",
#  "{'Called up share capital not paid': '100', 'Net assets': '100', 'Tssued share capital': nan, '100 Ordinary Shares of Â£ | each': '100', 'Total Shareholder funds': '100'}",
#  "{'Current Assets': '2124', 'Creditors: amounts falling due within one year': '-250', 'Net current assets (liabilities)': '1874', 'Total assets less current liabilities': '1874', 'Creditors: amounts falling due after more than one': nan, '(90.628)': '-90.628', 'year': nan, 'Total net assets (liabilities)': '-88754', 'Capital and reserves': '-88754'}",
#  "{'Called up share capital not paid': '1', 'Current Assets': '320', 'Prepayments and accrued income': '135', 'Net current assets (liabilities)': '455', 'Total assets less current liabilities': '456', 'Total net assets (liabilities)': '456', 'Capital and reserves': '456'}",
#  "{'Fixed Assets': '53', 'Current Assets': '3405', 'Creditors: amounts falling due within one year': '-360', 'Net current assets (liabilities)': '3045', 'Total assets less current liabilities': '3098', 'Total net assets (liabilities)': '3098', 'Capital and reserves': '3098'}",
#  "{'Fixed Assets': '33943', 'Current Assets': '201078', 'Creditors: amounts falling due within one year': '-59142', 'Net current assets (liabilities)': '141936', 'Total assets less current liabilities': '175879', 'Total net assets (liabilities)': '175879', 'Capital and reserves': '175879'}",
#  "{'Called up share capital not paid': '300', 'Net assets': '300', 'Tssued share capital': nan, '300 Ordinary Shares 1 of Â£ each': '300', 'Total Shareholder funds': '300'}",
#  "{'Called up share capital not paid': '0', 'Current assets': nan, 'Cash at bank and in hand': '100', 'Net assets': '100', 'Authorised share capital': nan, '100 ORDINARY SHARES of Â£1 each': '100', 'Issued share capital': nan, 'Total shareholder funds': '100', 'NOTES': nan, '1. During the year the company allotted 100 ordinary shares with an aggregate nominal value of Â£ 0, the': nan, 'consideration received by the company 0 was Â£': nan}",
#  "{'Called up share capital not paid': '1', 'Fixed Assets': '23000', 'Current Assets': '15474', 'Creditors: amounts falling due within one year': '-35344', 'Net current assets (liabilities)': '-19870', 'Total assets less current liabilities': '3131', 'Total net assets (liabilities)': '3131', 'Capital and reserves': '3131'}",
#  "{'Called up share capital not paid': '1', 'Net assets': '1', 'Tssued share capital': nan, '1 Ordinary Share 1 of Â£ each': '1', 'Total Shareholder funds': '1'}",
#  "{'Called up share capital not paid': '2', 'Fixed Assets': '675', 'Current Assets': '4403', 'Prepayments and accrued income': nan, 'Creditors: amounts falling due within one year': '0', 'Net current assets (liabilities)': '4403', 'Total assets less current liabilities': '5080', 'Creditors: amounts falling due after more than one year': '0', 'Provisions for liabilities': '0', 'Accruals and deferred income': '0', 'Total net assets (liabilities)': '5080', 'Capital and reserves': '5080'}",
#  "{'Fixed Assets': '6000', 'Current Assets': '9228', 'Creditors: amounts falling due within one year': '-10285', 'Net current assets (liabilities)': '-1057', 'Total assets less current liabilities': '4943', 'Total net assets (liabilities)': '4943', 'Capital and reserves': '4943'}",
#  "{'Called up share capital not paid': nan, 'Fixed Assets': nan, 'Current Assets': '11077', 'Prepayments and accrued income': nan, 'Creditors: amounts falling due within one year': '-4215', 'Net current assets (liabilities)': '6862', 'Total assets less current liabilities': '6862', 'Creditors: amounts falling due after more than one year': '0', 'Provisions for liabilities': '0', 'Accruals and deferred income': '0', 'Total net assets (liabilities)': '6862', 'Capital and reserves': '6862'}",
#  "{'Fixed Assets': '16232', 'Current Assets': '174721', 'Creditors: amounts falling due within one year': '-166173', 'Net current assets (liabilities)': '8548', 'Total assets less current liabilities': '24780', 'Total net assets (liabilities)': '24780', 'Capital and reserves': '24780'}",
#  "{'Called up share capital not paid': '100', 'Net assets': '100', 'Tssued share capital': nan, '100 Ordinary Shares of Â£ | each': '100', 'Total Shareholder funds': '100'}",
#  "{'Called up share capital not paid': '0.00', 'Current assets': nan, 'Cash at bank and in hand': '1.00', 'Net assets': '1.00', 'Issued share capital': nan, '1 Ordinary Shares of Â£1.00 each': '1.00', 'Total Shareholder funds': '1.00'}"]

# %%
len(dict_result)
# Out:
# 501

# %%
df
# Out:
#      Filename  Extracted Values
# 0    X8XUG1JD               NaN
# 1    X8XX0C57               NaN
# 2    X8XX02AX               NaN
# 3    X8XX0ANN               NaN
# 4    X8XX0BU1               NaN
# ..        ...               ...
# 495  X8Y4QWQB               NaN
# 496  X8Y4RM8X               NaN
# 497  X8Y4SRGR               NaN
# 498  X8Y4TD2I               NaN
# 499  X8Y4TGYA               NaN
#
# [500 rows x 2 columns]

# %%
dict_result = dict_result[1:]
df['Extracted Values'] = dict_result
df.to_csv('Submission57689.csv', index= False)
